# %%
import arckit

# %%
train_set, eval_set = arckit.load_data()
print(train_set[0])
# Out:
# <Task-train 00576224 | 2 train | 1 test>

# %%
print(train_set[0].train[0])
# Out:
# (array([[7, 9],
#        [4, 3]]), array([[7, 9, 7, 9, 7, 9],
#        [4, 3, 4, 3, 4, 3],
#        [9, 7, 9, 7, 9, 7],
#        [3, 4, 3, 4, 3, 4],
#        [7, 9, 7, 9, 7, 9],
#        [4, 3, 4, 3, 4, 3]]))
